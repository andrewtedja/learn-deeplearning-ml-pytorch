# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
### [CODE HERE] ###
### [CODE HERE] ###
### [CODE HERE] ###

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('JumlahKaryawan_WaktuProyek.csv') 

X = dataset.iloc[:, 0:-1].values
### [CODE HERE] ###

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = ### [CODE HERE] ###
### [CODE HERE] ###.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import ### [CODE HERE] ###
poly_reg = PolynomialFeatures(degree = 4) 
X_poly = ### [CODE HERE] ###.fit_transform(X) 
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X, y, color = 'red') 
### [CODE HERE] ###.plot(X, lin_reg.predict(X), color = 'blue') 
### [CODE HERE] ###.title('Jumlah Karyawan vs Waktu Proyek (Polynomial Regression)')
### [CODE HERE] ###.xlabel('Jumlah Karyawan')
### [CODE HERE] ###.ylabel('Waktu Proyek')
### [CODE HERE] ###.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y, color = 'red') 
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue') 
plt.title('Jumlah Karyawan vs Waktu Proyek (Polynomial Regression)')
plt.xlabel('Jumlah Karyawan')
plt.ylabel('Waktu Proyek')
### [CODE HERE] ###

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1)) 
plt.scatter(X, y, color = 'red') 
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue') 
plt.title('Jumlah Karyawan vs Waktu Proyek (Polynomial Regression)')
plt.xlabel('Jumlah Karyawan')
### [CODE HERE] ###
plt.show()
# Out:
# C:\Users\Ghandy\AppData\Local\Temp\ipykernel_8664\2762124034.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[40]])
# Out:
# array([127.8])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[40]]))
# Out:
# array([61.84207445])
